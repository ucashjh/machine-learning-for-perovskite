# %%
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'

# %%
data = pd.read_csv('data.csv')  # read csv
X = data.iloc[:, :29]  # X feature

# %% [markdown]
# # J_sc

# %%
# 1. data split
X_jsc = data.iloc[:, :27]  # X feature
y_jsc = data['Jsc']  # target feature
X_jsc_train, X_jsc_test, y_jsc_train, y_jsc_test = train_test_split(X_jsc, y_jsc, test_size=0.2, random_state=42)

# 2. lightgbm model
# parameter grid
param_grid_jsc = {
    'boosting_type': ['dart', 'goss'],
    'max_depth': [4, 6, 8, 50],
    'n_estimators': [100, 150],  
    'learning_rate': [0.01, 0.1, 0.5],
    'num_leaves': [20, 30],
    'verbosity': [-1],
}

# Initialize Gradient-boosted decision trees regressor
lgb_reg = lgb.LGBMRegressor(random_state=42) 

# 3. Grid searching for jsc
grid_jsc_search = GridSearchCV(
    estimator=lgb_reg,
    param_grid=param_grid_jsc,
    cv=5,
    scoring= {'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R ²
    n_jobs=-1,
    error_score='raise'
)

grid_jsc_search.fit(X_jsc_train, y_jsc_train)

# Best model for jsc
best_lgb_reg_jsc = grid_jsc_search.best_estimator_


# 4. Model evaluation on test set for jsc
y_jsc_pred = best_lgb_reg_jsc.predict(X_jsc_test)
mse_jsc = mean_squared_error(y_jsc_test, y_jsc_pred)
rmse_jsc = mse_jsc**0.5
mae_jsc = mean_absolute_error(y_jsc_test, y_jsc_pred)
r2_jsc = r2_score(y_jsc_test, y_jsc_pred)

print(f"Best Parameters for jsc: {grid_jsc_search.best_params_}")
print(f"MSE: {mse_jsc:.4f}, RMSE: {rmse_jsc:.4f}, R²: {r2_jsc:.4f}, MAE:{mae_jsc}")

# 5. Get cross-validation results for jsc
cv_jsc_results_df = pd.DataFrame(grid_jsc_search.cv_results_)
cv_jsc_results_df = cv_jsc_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for jsc
best_cv_jsc_score_r2 = grid_jsc_search.best_score_
best_cv_jsc_score_neg_mse = -grid_jsc_search.cv_results_['mean_test_neg_mse'][grid_jsc_search.best_index_]

for index, row in cv_jsc_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for jsc: {best_cv_jsc_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for jsc: {best_cv_jsc_score_neg_mse}")
print(f"Best parameters via GridSearchCV for jsc: {grid_jsc_search.best_params_}")


# 6. Visualization for jsc
plt.scatter(y_jsc_test, y_jsc_pred, alpha=0.5)
plt.plot([y_jsc_test.min(), y_jsc_test.max()], [y_jsc_test.min(), y_jsc_test.max()], 'r--')
plt.xlabel('True jsc')
plt.ylabel('Predicted jsc')
plt.title('True vs. Predicted jsc')
plt.show()
# Out:
# Best Parameters for jsc: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 8, 'n_estimators': 150, 'num_leaves': 30, 'verbosity': -1}
# MSE: 0.0046, RMSE: 0.0676, R²: 0.8589, MAE:0.04050944142093291
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 8, 'n_estimators': 150, 'num_leaves': 30, 'verbosity': -1}
# Mean Test R²: 0.8687186027168498
# Mean Test Neg MSE: -0.004518284053600505
# Std Test R²: 0.033800842273472874
# Std Test Neg MSE: 0.001501429092217265
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 6, 'n_estimators': 150, 'num_leaves': 30, 'verbosity': -1}
# Mean Test R²: 0.8678273477062518
# Mean Test Neg MSE: -0.0045136400059819955
# Std Test R²: 0.025180008026826003
# Std Test Neg MSE: 0.0012498874568206678
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 8, 'n_estimators': 100, 'num_leaves': 30, 'verbosity': -1}
# Mean Test R²: 0.8660560507823065
# Mean Test Neg MSE: -0.004592112412564672
# Std Test R²: 0.029931857803248866
# Std Test Neg MSE: 0.0013876953056578454
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 8, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.8651941049107916
# Mean Test Neg MSE: -0.004603922090164301
# Std Test R²: 0.027510119126208897
# Std Test Neg MSE: 0.0013080037790073032
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 6, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.8633588517004256
# Mean Test Neg MSE: -0.004659166771120892
# Std Test R²: 0.02424591574126831
# Std Test Neg MSE: 0.0012315542074191116
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 6, 'n_estimators': 100, 'num_leaves': 30, 'verbosity': -1}
# Mean Test R²: 0.863202032554591
# Mean Test Neg MSE: -0.004665374424869409
# Std Test R²: 0.025070444790210224
# Std Test Neg MSE: 0.0012617006884487946
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 50, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.862591410288634
# Mean Test Neg MSE: -0.004694646784691257
# Std Test R²: 0.02853272264335337
# Std Test Neg MSE: 0.0013421011981312816
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 8, 'n_estimators': 100, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.8622397173816301
# Mean Test Neg MSE: -0.0047001947447306595
# Std Test R²: 0.027150584446737073
# Std Test Neg MSE: 0.001314357858022258
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 50, 'n_estimators': 150, 'num_leaves': 30, 'verbosity': -1}
# Mean Test R²: 0.8617497022116624
# Mean Test Neg MSE: -0.004723583999951991
# Std Test R²: 0.029958089172570958
# Std Test Neg MSE: 0.0013759316253506772
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 50, 'n_estimators': 100, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.8609308994086262
# Mean Test Neg MSE: -0.004744737383831787
# Std Test R²: 0.02695465514167318
# Std Test Neg MSE: 0.00129987450342305
# --------------------------------------------------
# Best Cross-Validation R² for jsc: 0.8687186027168498
# Best Cross-Validation neg_mean_squared_error for jsc: 0.004518284053600505
# Best parameters via GridSearchCV for jsc: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 8, 'n_estimators': 150, 'num_leaves': 30, 'verbosity': -1}

# %% [markdown]
# # Voc

# %%
# 1. data split
X_voc = data.iloc[:, :27]  # X feature
y_voc = data['Voc']  # target feature
X_voc_train, X_voc_test, y_voc_train, y_voc_test = train_test_split(X_voc, y_voc, test_size=0.2, random_state=42)

# 2. lightgbm model
# parameter grid
param_grid_voc = {
    'boosting_type': ['dart'],
    'max_depth': [8, 10, 50],
    'min_sum_hessian_in_leaf': [0.001, 0.002],
    'n_estimators': [100, 150],  
    'learning_rate': [0.1, 0.5],
    'num_leaves': [20, 30],
    'max_bin' : [5, 25, 255],
    'verbosity': [-1]
}

# Initialize Gradient-boosted decision trees regressor
lgb_reg_voc = lgb.LGBMRegressor(random_state=42) 

# 3. Grid searching for voc
grid_voc_search = GridSearchCV(
    estimator=lgb_reg_voc,
    param_grid=param_grid_voc,
    cv=5,
    scoring= {'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R ²
    n_jobs=-1,
    error_score='raise'
)

grid_voc_search.fit(X_voc_train, y_voc_train)

# Best model for voc
best_lgb_reg_voc = grid_voc_search.best_estimator_

# 4. Model evaluation on test set for voc
y_voc_pred = best_lgb_reg_voc.predict(X_voc_test)
mse_voc = mean_squared_error(y_voc_test, y_voc_pred)
rmse_voc = mse_voc**0.5
mae_voc = mean_absolute_error(y_voc_test, y_voc_pred)
r2_voc = r2_score(y_voc_test, y_voc_pred)

print(f"Best Parameters for voc: {grid_voc_search.best_params_}")
print(f"MSE: {mse_voc:.4f}, RMSE: {rmse_voc:.4f}, R²: {r2_voc:.4f}, MAE:{mae_voc}")

# 5. Get cross-validation results for voc
cv_voc_results_df = pd.DataFrame(grid_voc_search.cv_results_)
cv_voc_results_df = cv_voc_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for voc
best_cv_voc_score_r2 = grid_voc_search.best_score_
best_cv_voc_score_neg_mse = -grid_voc_search.cv_results_['mean_test_neg_mse'][grid_voc_search.best_index_]

for index, row in cv_voc_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for voc: {best_cv_voc_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for voc: {best_cv_voc_score_neg_mse}")
print(f"Best parameters via GridSearchCV for voc: {grid_voc_search.best_params_}")

# 6. Visualization for voc
plt.scatter(y_voc_test, y_voc_pred, alpha=0.5)
plt.plot([y_voc_test.min(), y_voc_test.max()], [y_voc_test.min(), y_voc_test.max()], 'r--')
plt.xlabel('True voc')
plt.ylabel('Predicted voc')
plt.title('True vs. Predicted voc')
plt.show()
# Out:
# Best Parameters for voc: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_bin': 255, 'max_depth': 10, 'min_sum_hessian_in_leaf': 0.001, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# MSE: 0.0027, RMSE: 0.0516, R²: 0.9382, MAE:0.028940987395437254
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_bin': 255, 'max_depth': 10, 'min_sum_hessian_in_leaf': 0.002, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.9130061157812127
# Mean Test Neg MSE: -0.003647584540977457
# Std Test R²: 0.02329990272765907
# Std Test Neg MSE: 0.0011639399652880562
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_bin': 255, 'max_depth': 10, 'min_sum_hessian_in_leaf': 0.001, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.9130061157812127
# Mean Test Neg MSE: -0.003647584540977457
# Std Test R²: 0.02329990272765907
# Std Test Neg MSE: 0.0011639399652880562
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_bin': 255, 'max_depth': 8, 'min_sum_hessian_in_leaf': 0.002, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.9114536788209062
# Mean Test Neg MSE: -0.0036953127145233043
# Std Test R²: 0.021293835832626604
# Std Test Neg MSE: 0.0010840224661409603
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_bin': 255, 'max_depth': 8, 'min_sum_hessian_in_leaf': 0.001, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.9114536788209062
# Mean Test Neg MSE: -0.0036953127145233043
# Std Test R²: 0.021293835832626604
# Std Test Neg MSE: 0.0010840224661409603
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_bin': 255, 'max_depth': 10, 'min_sum_hessian_in_leaf': 0.001, 'n_estimators': 100, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.9110287163309941
# Mean Test Neg MSE: -0.0037228533136460956
# Std Test R²: 0.022990414910400055
# Std Test Neg MSE: 0.0011534463837671236
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_bin': 255, 'max_depth': 10, 'min_sum_hessian_in_leaf': 0.002, 'n_estimators': 100, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.9110287163309941
# Mean Test Neg MSE: -0.0037228533136460956
# Std Test R²: 0.022990414910400055
# Std Test Neg MSE: 0.0011534463837671236
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_bin': 255, 'max_depth': 50, 'min_sum_hessian_in_leaf': 0.002, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.9109144066435574
# Mean Test Neg MSE: -0.0037271524860073603
# Std Test R²: 0.021486195892629262
# Std Test Neg MSE: 0.0011016151524650508
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_bin': 255, 'max_depth': 50, 'min_sum_hessian_in_leaf': 0.001, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.9109144066435574
# Mean Test Neg MSE: -0.0037271524860073603
# Std Test R²: 0.021486195892629262
# Std Test Neg MSE: 0.0011016151524650508
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_bin': 255, 'max_depth': 50, 'min_sum_hessian_in_leaf': 0.002, 'n_estimators': 100, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.9093686943253078
# Mean Test Neg MSE: -0.0037886019680977946
# Std Test R²: 0.022038688817551826
# Std Test Neg MSE: 0.00112315446452019
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_bin': 255, 'max_depth': 50, 'min_sum_hessian_in_leaf': 0.001, 'n_estimators': 100, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.9093686943253078
# Mean Test Neg MSE: -0.0037886019680977946
# Std Test R²: 0.022038688817551826
# Std Test Neg MSE: 0.00112315446452019
# --------------------------------------------------
# Best Cross-Validation R² for voc: 0.9130061157812127
# Best Cross-Validation neg_mean_squared_error for voc: 0.003647584540977457
# Best parameters via GridSearchCV for voc: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_bin': 255, 'max_depth': 10, 'min_sum_hessian_in_leaf': 0.001, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}

# %% [markdown]
# # FF

# %%
# 1. data split
X_ff = data.iloc[:, :27]  # X feature
y_ff = data['FF']  # target feature
X_ff_train, X_ff_test, y_ff_train, y_ff_test = train_test_split(X_ff, y_ff, test_size=0.2, random_state=42)

# 2. lightgbm model
# parameter grid
param_grid_ff = {
    'boosting_type': ['dart', 'goss'],
    'max_depth': [4, 6, 8, 50],
    'n_estimators': [100, 150],  
    'learning_rate': [0.01, 0.1, 0.5],
    'num_leaves': [20, 30],
    'verbosity': [-1],
}

# Initialize Gradient-boosted decision trees regressor
lgb_reg_ff = lgb.LGBMRegressor(random_state=42) 

# 3. Grid searching for ff
grid_ff_search = GridSearchCV(
    estimator=lgb_reg_ff,
    param_grid=param_grid_ff,
    cv=5,
    scoring= {'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R ²
    n_jobs=-1,
    error_score='raise'
)

grid_ff_search.fit(X_ff_train, y_ff_train)

# Best model for ff
best_lgb_reg_ff = grid_ff_search.best_estimator_

# 4. Model evaluation on test set for ff
y_ff_pred = best_lgb_reg_ff.predict(X_ff_test)
mse_ff = mean_squared_error(y_ff_test, y_ff_pred)
rmse_ff = mse_ff**0.5
mae_ff = mean_absolute_error(y_ff_test, y_ff_pred)
r2_ff = r2_score(y_ff_test, y_ff_pred)

print(f"Best Parameters for ff: {grid_ff_search.best_params_}")
print(f"MSE: {mse_ff:.4f}, RMSE: {rmse_ff:.4f}, R²: {r2_ff:.4f}, MAE:{mae_ff}")

# 5. Get cross-validation results for ff
cv_ff_results_df = pd.DataFrame(grid_ff_search.cv_results_)
cv_ff_results_df = cv_ff_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for ff
best_cv_ff_score_r2 = grid_ff_search.best_score_
best_cv_ff_score_neg_mse = -grid_ff_search.cv_results_['mean_test_neg_mse'][grid_ff_search.best_index_]

for index, row in cv_ff_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for ff: {best_cv_ff_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for ff: {best_cv_ff_score_neg_mse}")
print(f"Best parameters via GridSearchCV for ff: {grid_ff_search.best_params_}")

# 6. Visualization for ff
plt.scatter(y_ff_test, y_ff_pred, alpha=0.5)
plt.plot([y_ff_test.min(), y_ff_test.max()], [y_ff_test.min(), y_ff_test.max()], 'r--')
plt.xlabel('True ff')
plt.ylabel('Predicted ff')
plt.title('True vs. Predicted ff')
plt.show()
# Out:
# Best Parameters for ff: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 6, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# MSE: 0.0073, RMSE: 0.0852, R²: 0.6305, MAE:0.05458105111187018
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 6, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.6072345773596043
# Mean Test Neg MSE: -0.006600442861893268
# Std Test R²: 0.05175946113542142
# Std Test Neg MSE: 0.0015154579363369917
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.605740238289233
# Mean Test Neg MSE: -0.006630104262152364
# Std Test R²: 0.044755572448674404
# Std Test Neg MSE: 0.0014401582983720532
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 150, 'num_leaves': 30, 'verbosity': -1}
# Mean Test R²: 0.605740238289233
# Mean Test Neg MSE: -0.006630104262152364
# Std Test R²: 0.044755572448674404
# Std Test Neg MSE: 0.0014401582983720532
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 6, 'n_estimators': 150, 'num_leaves': 30, 'verbosity': -1}
# Mean Test R²: 0.6016316640085714
# Mean Test Neg MSE: -0.00668311230414612
# Std Test R²: 0.05608830678338241
# Std Test Neg MSE: 0.0015327155312275247
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 6, 'n_estimators': 100, 'num_leaves': 30, 'verbosity': -1}
# Mean Test R²: 0.5994252614517126
# Mean Test Neg MSE: -0.0067339125756383875
# Std Test R²: 0.054234691497287386
# Std Test Neg MSE: 0.0015727279789396074
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 6, 'n_estimators': 100, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.5991822662963242
# Mean Test Neg MSE: -0.006713967714635676
# Std Test R²: 0.05596294876374168
# Std Test Neg MSE: 0.0015062737616790747
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 8, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.5981384794064312
# Mean Test Neg MSE: -0.006743802988297134
# Std Test R²: 0.06088574897619829
# Std Test Neg MSE: 0.0016050266902896146
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 8, 'n_estimators': 100, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.5965486191963956
# Mean Test Neg MSE: -0.0067999562810876855
# Std Test R²: 0.06205608653920797
# Std Test Neg MSE: 0.0017365104019355464
# --------------------------------------------------
# Params: {'boosting_type': 'goss', 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 150, 'num_leaves': 30, 'verbosity': -1}
# Mean Test R²: 0.5942398133262244
# Mean Test Neg MSE: -0.006831999736522436
# Std Test R²: 0.043954858674411366
# Std Test Neg MSE: 0.0015058632343307868
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 4, 'n_estimators': 100, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.5935991662896515
# Mean Test Neg MSE: -0.006857603576088352
# Std Test R²: 0.043560775736882426
# Std Test Neg MSE: 0.0015626886498228641
# --------------------------------------------------
# Best Cross-Validation R² for ff: 0.6072345773596043
# Best Cross-Validation neg_mean_squared_error for ff: 0.006600442861893268
# Best parameters via GridSearchCV for ff: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 6, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}

# %% [markdown]
# # PCE

# %%
# 1. data split
X_pce = data.iloc[:, :27]  # X feature
y_pce = data['PCE']  # target feature
X_pce_train, X_pce_test, y_pce_train, y_pce_test = train_test_split(X_pce, y_pce, test_size=0.2, random_state=42)

# 2. lightgbm model
# parameter grid
param_grid_pce = {
    'boosting_type': ['dart', 'goss'],
    'max_depth': [4, 6, 8, 50, 70],
    'n_estimators': [100, 150, 200],  
    'learning_rate': [0.1, 0.5, 0.7],
    'num_leaves': [20, 25, 30],
    'verbosity': [-1],
}

# Initialize Gradient-boosted decision trees regressor
lgb_reg_pce = lgb.LGBMRegressor(random_state=42) 

# 3. Grid searching for pce
grid_pce_search = GridSearchCV(
    estimator=lgb_reg_pce,
    param_grid=param_grid_pce,
    cv=5,
    scoring= {'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R ²
    n_jobs=-1,
    error_score='raise'
)

grid_pce_search.fit(X_pce_train, y_pce_train)

# Best model for pce
best_lgb_reg_pce = grid_pce_search.best_estimator_

# 4. Model evaluation on test set for pce
y_pce_pred = best_lgb_reg_pce.predict(X_pce_test)
mse_pce = mean_squared_error(y_pce_test, y_pce_pred)
rmse_pce = mse_pce**0.5
mae_pce = mean_absolute_error(y_pce_test, y_pce_pred)
r2_pce = r2_score(y_pce_test, y_pce_pred)

print(f"Best Parameters for pce: {grid_pce_search.best_params_}")
print(f"MSE: {mse_pce:.4f}, RMSE: {rmse_pce:.4f}, R²: {r2_pce:.4f}, MAE:{mae_pce}")

# 5. Get cross-validation results for pce
cv_pce_results_df = pd.DataFrame(grid_pce_search.cv_results_)
cv_pce_results_df = cv_pce_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for pce
best_cv_pce_score_r2 = grid_pce_search.best_score_
best_cv_pce_score_neg_mse = -grid_pce_search.cv_results_['mean_test_neg_mse'][grid_pce_search.best_index_]

for index, row in cv_pce_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for pce: {best_cv_pce_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for pce: {best_cv_pce_score_neg_mse}")
print(f"Best parameters via GridSearchCV for pce: {grid_pce_search.best_params_}")

# 6. Visualization for pce
plt.scatter(y_pce_test, y_pce_pred, alpha=0.5)
plt.plot([y_pce_test.min(), y_pce_test.max()], [y_pce_test.min(), y_pce_test.max()], 'r--')
plt.xlabel('True pce')
plt.ylabel('Predicted pce')
plt.title('True vs. Predicted pce')
plt.show()
# Out:
# Best Parameters for pce: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 50, 'n_estimators': 200, 'num_leaves': 20, 'verbosity': -1}
# MSE: 0.0054, RMSE: 0.0736, R²: 0.8559, MAE:0.05041750833608373
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 50, 'n_estimators': 200, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.8376374353958932
# Mean Test Neg MSE: -0.006062183277061096
# Std Test R²: 0.029944180952045554
# Std Test Neg MSE: 0.0010085739365851688
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 70, 'n_estimators': 200, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.8376374353958932
# Mean Test Neg MSE: -0.006062183277061096
# Std Test R²: 0.029944180952045554
# Std Test Neg MSE: 0.0010085739365851688
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 50, 'n_estimators': 200, 'num_leaves': 30, 'verbosity': -1}
# Mean Test R²: 0.8372268092519638
# Mean Test Neg MSE: -0.0060984837338639445
# Std Test R²: 0.027636568329175257
# Std Test Neg MSE: 0.001009980626578319
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 70, 'n_estimators': 200, 'num_leaves': 30, 'verbosity': -1}
# Mean Test R²: 0.8372268092519638
# Mean Test Neg MSE: -0.0060984837338639445
# Std Test R²: 0.027636568329175257
# Std Test Neg MSE: 0.001009980626578319
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 50, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.8365136651533535
# Mean Test Neg MSE: -0.00609937418168834
# Std Test R²: 0.029212788983136076
# Std Test Neg MSE: 0.0009523844173606621
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 70, 'n_estimators': 150, 'num_leaves': 20, 'verbosity': -1}
# Mean Test R²: 0.8365136651533535
# Mean Test Neg MSE: -0.00609937418168834
# Std Test R²: 0.029212788983136076
# Std Test Neg MSE: 0.0009523844173606621
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 8, 'n_estimators': 200, 'num_leaves': 30, 'verbosity': -1}
# Mean Test R²: 0.8348312265767677
# Mean Test Neg MSE: -0.006176844807514048
# Std Test R²: 0.024705806616050693
# Std Test Neg MSE: 0.0008584849445730826
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 70, 'n_estimators': 200, 'num_leaves': 25, 'verbosity': -1}
# Mean Test R²: 0.8338911485035878
# Mean Test Neg MSE: -0.006221556101295529
# Std Test R²: 0.02753253179274811
# Std Test Neg MSE: 0.0010000525130444307
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 50, 'n_estimators': 200, 'num_leaves': 25, 'verbosity': -1}
# Mean Test R²: 0.8338911485035878
# Mean Test Neg MSE: -0.006221556101295529
# Std Test R²: 0.02753253179274811
# Std Test Neg MSE: 0.0010000525130444307
# --------------------------------------------------
# Params: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 50, 'n_estimators': 150, 'num_leaves': 30, 'verbosity': -1}
# Mean Test R²: 0.8337767669632363
# Mean Test Neg MSE: -0.006216460136752875
# Std Test R²: 0.02691117696356881
# Std Test Neg MSE: 0.0009396656238127366
# --------------------------------------------------
# Best Cross-Validation R² for pce: 0.8376374353958932
# Best Cross-Validation neg_mean_squared_error for pce: 0.006062183277061096
# Best parameters via GridSearchCV for pce: {'boosting_type': 'dart', 'learning_rate': 0.5, 'max_depth': 50, 'n_estimators': 200, 'num_leaves': 20, 'verbosity': -1}

# %% [markdown]
# # SHapley Additive exPlanations

# %%
import shap
import numpy as np

# %% [markdown]
# ### For pce

# %%
explainer = shap.explainers.Permutation(best_lgb_reg_pce.predict, X_pce)
shap_values_pce = explainer(X_pce)
# Out:
# PermutationExplainer explainer: 981it [03:38,  4.26it/s]

# %%
### summary_plot
shap.summary_plot(shap_values_pce, X_pce, max_display=10)
# Out:
# C:\Users\82308\AppData\Local\Temp\ipykernel_15304\2604488546.py:2: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values_pce, X_pce, max_display=10)

# %%
# Output feature importance ranking
shap_values_array_pce = shap_values_pce.values 
shap_values_abs_mean = np.abs(shap_values_array_pce).mean(axis=0)  # 
feature_importance = pd.DataFrame({
    'feature': X_pce_train.columns,
    'importance': shap_values_abs_mean
})
feature_importance = feature_importance.sort_values(by='importance', ascending=False)
feature_importance
# Out:
#                  feature  importance
# 3               Pb_ratio    0.070678
# 1               FA_ratio    0.054506
# 12  effective area (cm2)    0.033250
# 24          anneal_T (℃)    0.017846
# 7               Br_ratio    0.014181
# 18            dissolvent    0.013999
# 6                I_ratio    0.013691
# 13            additive_O    0.013112
# 16           passivation    0.011497
# 2               Cs_ratio    0.011263
# 11           ne_eletrode    0.009762
# 20         coated1_t (s)    0.009591
# 22         coated2_t (s)    0.009510
# 25        anneal_t (min)    0.006680
# 0               MA_ratio    0.006420
# 10               HTL/HTM    0.006180
# 19        coated1_s(rpm)    0.005969
# 23          anti-solvent    0.005699
# 17                  step    0.004014
# 9                ETL/ETM    0.003930
# 14            additive_I    0.002887
# 21        coated2_s(rpm)    0.002743
# 5            other_ratio    0.002475
# 15            additive_H    0.002443
# 4               Sn_ratio    0.001957
# 8           po_electrode    0.001632

# %%
X_pce_train = pd.DataFrame(X_pce_train)
