# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data.csv')  # read csv
X = data.iloc[:, :26]  # X feature

# %% [markdown]
# ### **J_sc**

# %%
# 1. data split
X_jsc = data.iloc[:, :26]  # X feature
y_jsc = data['Jsc (mA/cm2)']  # target feature
X_jsc_train, X_jsc_test, y_jsc_train, y_jsc_test = train_test_split(X_jsc, y_jsc, test_size=0.2, random_state=42)

# 2. GBDT model
# parameter grid
param_grid_jsc = {
    'learning_rate': [0.1, 0.15, 0.2],
    'n_estimators': [100, 150, 200],
    'subsample': [0.8, 0.9, 1.0],
    'max_depth': [3, 5, 7],
    'max_features': [None, 'sqrt', 'log2']
}

# Initialize Gradient-boosted decision trees regressor
gbdt_reg = GradientBoostingRegressor(random_state=42) 

# 3. Grid searching for jsc
grid_jsc_search = GridSearchCV(
    estimator=gbdt_reg,
    param_grid=param_grid_jsc,
    cv=5,
    scoring= {'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R ²
    n_jobs=-1
)

grid_jsc_search.fit(X_jsc_train, y_jsc_train)

# Best model for jsc
best_gbdt_reg_jsc = grid_jsc_search.best_estimator_


# 4. Model evaluation on test set for jsc
y_jsc_pred = best_gbdt_reg_jsc.predict(X_jsc_test)
mse_jsc = mean_squared_error(y_jsc_test, y_jsc_pred)
rmse_jsc = mse_jsc**0.5
mae_jsc = mean_absolute_error(y_jsc_test, y_jsc_pred)
r2_jsc = r2_score(y_jsc_test, y_jsc_pred)

print(f"Best Parameters for jsc: {grid_jsc_search.best_params_}")
print(f"MSE: {mse_jsc:.4f}, RMSE: {rmse_jsc:.4f}, R²: {r2_jsc:.4f}, MAE:{mae_jsc}")

# 5. Get cross-validation results for jsc
cv_jsc_results_df = pd.DataFrame(grid_jsc_search.cv_results_)
cv_jsc_results_df = cv_jsc_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for jsc
best_cv_jsc_score_r2 = grid_jsc_search.best_score_
best_cv_jsc_score_neg_mse = -grid_jsc_search.cv_results_['mean_test_neg_mse'][grid_jsc_search.best_index_]

for index, row in cv_jsc_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for jsc: {best_cv_jsc_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for jsc: {best_cv_jsc_score_neg_mse}")
print(f"Best parameters via GridSearchCV for jsc: {grid_jsc_search.best_params_}")


# 6. Visualization for jsc
plt.scatter(y_jsc_test, y_jsc_pred, alpha=0.5)
plt.plot([y_jsc_test.min(), y_jsc_test.max()], [y_jsc_test.min(), y_jsc_test.max()], 'r--')
plt.xlabel('True jsc')
plt.ylabel('Predicted jsc')
plt.title('True vs. Predicted jsc')
plt.show()
# Out:
# Best Parameters for jsc: {'learning_rate': 0.1, 'max_depth': 7, 'max_features': 'log2', 'n_estimators': 100, 'subsample': 0.9}
# MSE: 0.0042, RMSE: 0.0649, R²: 0.8817, MAE:0.03913672159738497
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'max_features': 'log2', 'n_estimators': 100, 'subsample': 0.9}
# Mean Test R²: 0.8681316393007688
# Mean Test Neg MSE: -0.0045497039724844
# Std Test R²: 0.03860878707461164
# Std Test Neg MSE: 0.0014224042784332822
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'max_features': 'log2', 'n_estimators': 150, 'subsample': 0.9}
# Mean Test R²: 0.8665157602466307
# Mean Test Neg MSE: -0.004605752481111022
# Std Test R²: 0.03956619970736612
# Std Test Neg MSE: 0.0014531191839032849
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'max_features': 'log2', 'n_estimators': 200, 'subsample': 0.9}
# Mean Test R²: 0.8660877497297637
# Mean Test Neg MSE: -0.004619440599687254
# Std Test R²: 0.03915987132461655
# Std Test Neg MSE: 0.001439158693177117
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'max_features': 'sqrt', 'n_estimators': 100, 'subsample': 0.9}
# Mean Test R²: 0.8650750554567315
# Mean Test Neg MSE: -0.004646190234078703
# Std Test R²: 0.041107905365857525
# Std Test Neg MSE: 0.0014927926416291387
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'max_features': 'sqrt', 'n_estimators': 150, 'subsample': 0.9}
# Mean Test R²: 0.8643410611556831
# Mean Test Neg MSE: -0.004673724605895184
# Std Test R²: 0.041703305022723944
# Std Test Neg MSE: 0.001516586377672709
# --------------------------------------------------
# Params: {'learning_rate': 0.15, 'max_depth': 7, 'max_features': 'log2', 'n_estimators': 150, 'subsample': 0.9}
# Mean Test R²: 0.8634421474438907
# Mean Test Neg MSE: -0.00470876525654884
# Std Test R²: 0.03347804194857471
# Std Test Neg MSE: 0.0012600913584346128
# --------------------------------------------------
# Params: {'learning_rate': 0.15, 'max_depth': 7, 'max_features': 'log2', 'n_estimators': 100, 'subsample': 0.9}
# Mean Test R²: 0.863347894833536
# Mean Test Neg MSE: -0.004710181729056575
# Std Test R²: 0.03386647066664636
# Std Test Neg MSE: 0.001264112609461682
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'max_features': 'sqrt', 'n_estimators': 200, 'subsample': 0.9}
# Mean Test R²: 0.8630566308671683
# Mean Test Neg MSE: -0.004716105044424336
# Std Test R²: 0.04242922414448931
# Std Test Neg MSE: 0.0015366577664995941
# --------------------------------------------------
# Params: {'learning_rate': 0.15, 'max_depth': 7, 'max_features': 'log2', 'n_estimators': 200, 'subsample': 0.9}
# Mean Test R²: 0.8626305963047398
# Mean Test Neg MSE: -0.004735185519043084
# Std Test R²: 0.032895531021771084
# Std Test Neg MSE: 0.0012402522756064772
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'max_features': 'log2', 'n_estimators': 100, 'subsample': 1.0}
# Mean Test R²: 0.861865754936812
# Mean Test Neg MSE: -0.004758626613267515
# Std Test R²: 0.035021850663228465
# Std Test Neg MSE: 0.0013042887977677074
# --------------------------------------------------
# Best Cross-Validation R² for jsc: 0.8681316393007688
# Best Cross-Validation neg_mean_squared_error for jsc: 0.0045497039724844
# Best parameters via GridSearchCV for jsc: {'learning_rate': 0.1, 'max_depth': 7, 'max_features': 'log2', 'n_estimators': 100, 'subsample': 0.9}

# %% [markdown]
# ### **V_oc**

# %%
# 1. data split
X_voc = data.iloc[:, :26]  # X feature
y_voc = data['Voc (V)']  # target feature
X_voc_train, X_voc_test, y_voc_train, y_voc_test = train_test_split(X_voc, y_voc, test_size=0.2, random_state=42)

# 2. GBDT model
# parameter grid
param_grid_voc = {
    'learning_rate': [0.1, 0.15, 0.2],
    'n_estimators': [100, 150, 200],
    'subsample': [0.8, 0.9, 1.0],
    'max_depth': [3, 5, 7],
    'max_features': [None, 'sqrt', 'log2']
}

# Initialize Gradient-boosted decision trees regressor
gbdt_reg_voc = GradientBoostingRegressor(random_state=42) 

# 3. Grid searching for voc
grid_voc_search = GridSearchCV(
    estimator=gbdt_reg_voc,
    param_grid=param_grid_voc,
    cv=5,
    scoring= {'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R ²
    n_jobs=-1
)

grid_voc_search.fit(X_voc_train, y_voc_train)

# Best model for voc
best_gbdt_reg_voc = grid_voc_search.best_estimator_


# 4. Model evaluation on test set for voc
y_voc_pred = best_gbdt_reg_voc.predict(X_voc_test)
mse_voc = mean_squared_error(y_voc_test, y_voc_pred)
rmse_voc = mse_voc**0.5
mae_voc = mean_absolute_error(y_voc_test, y_voc_pred)
r2_voc = r2_score(y_voc_test, y_voc_pred)

print(f"Best Parameters for voc: {grid_voc_search.best_params_}")
print(f"MSE: {mse_voc:.4f}, RMSE: {rmse_voc:.4f}, R²: {r2_voc:.4f}, MAE:{mae_voc}")

# 5. Get cross-validation results for voc
cv_voc_results_df = pd.DataFrame(grid_voc_search.cv_results_)
cv_voc_results_df = cv_voc_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for voc
best_cv_voc_score_r2 = grid_voc_search.best_score_
best_cv_voc_score_neg_mse = -grid_voc_search.cv_results_['mean_test_neg_mse'][grid_voc_search.best_index_]

for index, row in cv_voc_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for voc: {best_cv_voc_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for voc: {best_cv_voc_score_neg_mse}")
print(f"Best parameters via GridSearchCV for voc: {grid_voc_search.best_params_}")


# 6. Visualization for voc
plt.scatter(y_voc_test, y_voc_pred, alpha=0.5)
plt.plot([y_voc_test.min(), y_voc_test.max()], [y_voc_test.min(), y_voc_test.max()], 'r--')
plt.xlabel('True voc')
plt.ylabel('Predicted voc')
plt.title('True vs. Predicted voc')
plt.show()
# Out:
# Best Parameters for voc: {'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'subsample': 1.0}
# MSE: 0.0081, RMSE: 0.0898, R²: 0.9112, MAE:0.053675513292448795
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'subsample': 1.0}
# Mean Test R²: 0.9146189337903801
# Mean Test Neg MSE: -0.006975329741045945
# Std Test R²: 0.028175741857340654
# Std Test Neg MSE: 0.0020168137096746013
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 150, 'subsample': 1.0}
# Mean Test R²: 0.9144906072632658
# Mean Test Neg MSE: -0.006978561513488919
# Std Test R²: 0.03054025618615325
# Std Test Neg MSE: 0.0022152975681819453
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 3, 'max_features': None, 'n_estimators': 200, 'subsample': 1.0}
# Mean Test R²: 0.9144017011565033
# Mean Test Neg MSE: -0.006967091477434094
# Std Test R²: 0.03137927773529113
# Std Test Neg MSE: 0.002173501260183106
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'subsample': 1.0}
# Mean Test R²: 0.9136205287729771
# Mean Test Neg MSE: -0.007040639172982389
# Std Test R²: 0.03326177224419526
# Std Test Neg MSE: 0.002431760441295584
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 3, 'max_features': None, 'n_estimators': 150, 'subsample': 1.0}
# Mean Test R²: 0.9132902022943739
# Mean Test Neg MSE: -0.00706023731209543
# Std Test R²: 0.0302776454505714
# Std Test Neg MSE: 0.0020767961861792006
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'subsample': 0.9}
# Mean Test R²: 0.9129166225485964
# Mean Test Neg MSE: -0.007095958621461085
# Std Test R²: 0.03489784464846363
# Std Test Neg MSE: 0.0025024089692942575
# --------------------------------------------------
# Params: {'learning_rate': 0.15, 'max_depth': 3, 'max_features': None, 'n_estimators': 150, 'subsample': 1.0}
# Mean Test R²: 0.9127657926827453
# Mean Test Neg MSE: -0.007104599023361585
# Std Test R²: 0.03427400994755961
# Std Test Neg MSE: 0.0024199132781288777
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'max_features': 'log2', 'n_estimators': 100, 'subsample': 0.9}
# Mean Test R²: 0.9125046360481083
# Mean Test Neg MSE: -0.0071077315450166515
# Std Test R²: 0.036772470778492175
# Std Test Neg MSE: 0.0026599381284933476
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'max_features': 'log2', 'n_estimators': 100, 'subsample': 1.0}
# Mean Test R²: 0.9124166193490286
# Mean Test Neg MSE: -0.00710302429782333
# Std Test R²: 0.041712828861835194
# Std Test Neg MSE: 0.0031231183928178328
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'max_features': 'sqrt', 'n_estimators': 150, 'subsample': 0.8}
# Mean Test R²: 0.9123564061437881
# Mean Test Neg MSE: -0.007095672657084587
# Std Test R²: 0.04226130249619008
# Std Test Neg MSE: 0.003069397875942714
# --------------------------------------------------
# Best Cross-Validation R² for voc: 0.9146189337903801
# Best Cross-Validation neg_mean_squared_error for voc: 0.006975329741045945
# Best parameters via GridSearchCV for voc: {'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'subsample': 1.0}

# %% [markdown]
# ### **FF**

# %%
# 1. data split
X_ff = data.iloc[:, :26]  # X feature
y_ff = data['FF']  # target feature
X_ff_train, X_ff_test, y_ff_train, y_ff_test = train_test_split(X_ff, y_ff, test_size=0.2, random_state=42)

# 2. GBDT model
# parameter grid
param_grid_ff = {
    'learning_rate': [0.1, 0.15, 0.2],
    'n_estimators': [100, 150, 200],
    'subsample': [0.8, 0.9, 1.0],
    'max_depth': [3, 5, 7],
    'max_features': [None, 'sqrt', 'log2']
}

# Initialize Gradient-boosted decision trees regressor
gbdt_reg_ff = GradientBoostingRegressor(random_state=42) 

# 3. Grid searching for ff
grid_ff_search = GridSearchCV(
    estimator=gbdt_reg_ff,
    param_grid=param_grid_ff,
    cv=5,
    scoring= {'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R ²
    n_jobs=-1
)

grid_ff_search.fit(X_ff_train, y_ff_train)

# Best model for ff
best_gbdt_reg_ff = grid_ff_search.best_estimator_


# 4. Model evaluation on test set for ff
y_ff_pred = best_gbdt_reg_ff.predict(X_ff_test)
mse_ff = mean_squared_error(y_ff_test, y_ff_pred)
rmse_ff = mse_ff**0.5
mae_ff = mean_absolute_error(y_ff_test, y_ff_pred)
r2_ff = r2_score(y_ff_test, y_ff_pred)

print(f"Best Parameters for ff: {grid_ff_search.best_params_}")
print(f"MSE: {mse_ff:.4f}, RMSE: {rmse_ff:.4f}, R²: {r2_ff:.4f}, MAE:{mae_ff}")

# 5. Get cross-validation results for ff
cv_ff_results_df = pd.DataFrame(grid_ff_search.cv_results_)
cv_ff_results_df = cv_ff_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for ff
best_cv_ff_score_r2 = grid_ff_search.best_score_
best_cv_ff_score_neg_mse = -grid_ff_search.cv_results_['mean_test_neg_mse'][grid_ff_search.best_index_]

for index, row in cv_ff_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for ff: {best_cv_ff_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for ff: {best_cv_ff_score_neg_mse}")
print(f"Best parameters via GridSearchCV for ff: {grid_ff_search.best_params_}")


# 6. Visualization for ff
plt.scatter(y_ff_test, y_ff_pred, alpha=0.5)
plt.plot([y_ff_test.min(), y_ff_test.max()], [y_ff_test.min(), y_ff_test.max()], 'r--')
plt.xlabel('True ff')
plt.ylabel('Predicted ff')
plt.title('True vs. Predicted ff')
plt.show()
# Out:
# Best Parameters for ff: {'learning_rate': 0.2, 'max_depth': 5, 'max_features': None, 'n_estimators': 100, 'subsample': 0.9}
# MSE: 0.0041, RMSE: 0.0638, R²: 0.5624, MAE:0.04675016695611078
# Params: {'learning_rate': 0.2, 'max_depth': 5, 'max_features': None, 'n_estimators': 100, 'subsample': 0.9}
# Mean Test R²: 0.6509244108745812
# Mean Test Neg MSE: -0.003586965935961954
# Std Test R²: 0.05320841374876023
# Std Test Neg MSE: 0.0007290323461739589
# --------------------------------------------------
# Params: {'learning_rate': 0.15, 'max_depth': 7, 'max_features': 'sqrt', 'n_estimators': 100, 'subsample': 1.0}
# Mean Test R²: 0.6501882934716718
# Mean Test Neg MSE: -0.003630324140493635
# Std Test R²: 0.07587963899051402
# Std Test Neg MSE: 0.0009941300946176177
# --------------------------------------------------
# Params: {'learning_rate': 0.15, 'max_depth': 7, 'max_features': 'sqrt', 'n_estimators': 150, 'subsample': 1.0}
# Mean Test R²: 0.6482415131521931
# Mean Test Neg MSE: -0.0036514436334758524
# Std Test R²: 0.07653483524698827
# Std Test Neg MSE: 0.001004277299591777
# --------------------------------------------------
# Params: {'learning_rate': 0.15, 'max_depth': 7, 'max_features': 'sqrt', 'n_estimators': 200, 'subsample': 1.0}
# Mean Test R²: 0.6477643346175236
# Mean Test Neg MSE: -0.0036567751417306018
# Std Test R²: 0.07666130646715458
# Std Test Neg MSE: 0.0010071230726212015
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 150, 'subsample': 1.0}
# Mean Test R²: 0.6459925068124577
# Mean Test Neg MSE: -0.0036730960812919066
# Std Test R²: 0.0671946860239615
# Std Test Neg MSE: 0.0009433936421088463
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'subsample': 1.0}
# Mean Test R²: 0.6447947911463524
# Mean Test Neg MSE: -0.0036851174275480646
# Std Test R²: 0.06767715184994612
# Std Test Neg MSE: 0.0009441614172837266
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'max_features': None, 'n_estimators': 150, 'subsample': 1.0}
# Mean Test R²: 0.643608547647462
# Mean Test Neg MSE: -0.0036801688728104265
# Std Test R²: 0.0660915254144304
# Std Test Neg MSE: 0.0008651677352889784
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'max_features': None, 'n_estimators': 200, 'subsample': 1.0}
# Mean Test R²: 0.6429694601712295
# Mean Test Neg MSE: -0.0036873636678000457
# Std Test R²: 0.06535406862781404
# Std Test Neg MSE: 0.0008626318765799734
# --------------------------------------------------
# Params: {'learning_rate': 0.2, 'max_depth': 5, 'max_features': None, 'n_estimators': 150, 'subsample': 0.9}
# Mean Test R²: 0.642518119272483
# Mean Test Neg MSE: -0.0036716185073471267
# Std Test R²: 0.0497242200171813
# Std Test Neg MSE: 0.0007095437233425907
# --------------------------------------------------
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 150, 'subsample': 0.9}
# Mean Test R²: 0.6418979196081087
# Mean Test Neg MSE: -0.0036786674202333933
# Std Test R²: 0.08576207060107723
# Std Test Neg MSE: 0.000989088889557798
# --------------------------------------------------
# Best Cross-Validation R² for ff: 0.6509244108745812
# Best Cross-Validation neg_mean_squared_error for ff: 0.003586965935961954
# Best parameters via GridSearchCV for ff: {'learning_rate': 0.2, 'max_depth': 5, 'max_features': None, 'n_estimators': 100, 'subsample': 0.9}

# %% [markdown]
# ### **PCE**

# %%
# 1. data split
X_pce = data.iloc[:, :26]  # X feature
y_pce = data['PCE (%)']  # target feature
X_pce_train, X_pce_test, y_pce_train, y_pce_test = train_test_split(X_pce, y_pce, test_size=0.2, random_state=42)

# 2. GBDT model
# parameter grid
param_grid_pce = {
    'learning_rate': [0.01, 0.05, 0.1, 0.15, 0.17, 0.2],
    'n_estimators': [150, 200],
    'subsample': [0.9, 0.95, 0.97, 1.0],
    'max_depth': [5, 7, 9],
    'max_features': [None, 'sqrt', 'log2']
}

# Initialize Gradient-boosted decision trees regressor
gbdt_reg_pce = GradientBoostingRegressor(random_state=42) 

# 3. Grid searching for pce
grid_pce_search = GridSearchCV(
    estimator=gbdt_reg_pce,
    param_grid=param_grid_pce,
    cv=5,
    scoring= {'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R ²
    n_jobs=-1
)

grid_pce_search.fit(X_pce_train, y_pce_train)

# Best model for pce
best_gbdt_reg_pce = grid_pce_search.best_estimator_


# 4. Model evaluation on test set for pce
y_pce_pred = best_gbdt_reg_pce.predict(X_pce_test)
mse_pce = mean_squared_error(y_pce_test, y_pce_pred)
rmse_pce = mse_pce**0.5
mae_pce = mean_absolute_error(y_pce_test, y_pce_pred)
r2_pce = r2_score(y_pce_test, y_pce_pred)

print(f"Best Parameters for pce: {grid_pce_search.best_params_}")
print(f"MSE: {mse_pce:.4f}, RMSE: {rmse_pce:.4f}, MAE:{mae_pce:4f}, R²: {r2_pce:.4f} ")

# 5. Get cross-validation results for pce
cv_pce_results_df = pd.DataFrame(grid_pce_search.cv_results_)
cv_pce_results_df = cv_pce_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for pce
best_cv_pce_score_r2 = grid_pce_search.best_score_
best_cv_pce_score_neg_mse = -grid_pce_search.cv_results_['mean_test_neg_mse'][grid_pce_search.best_index_]

for index, row in cv_pce_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for pce: {best_cv_pce_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for pce: {best_cv_pce_score_neg_mse}")
print(f"Best parameters via GridSearchCV for pce: {grid_pce_search.best_params_}")


# 6. Visualization for pce
plt.scatter(y_pce_test, y_pce_pred, alpha=0.5)
plt.plot([y_pce_test.min(), y_pce_test.max()], [y_pce_test.min(), y_pce_test.max()], 'r--')
plt.xlabel('True pce')
plt.ylabel('Predicted pce')
plt.title('True vs. Predicted pce')
plt.show()
# Out:
# Best Parameters for pce: {'learning_rate': 0.05, 'max_depth': 9, 'max_features': 'sqrt', 'n_estimators': 150, 'subsample': 0.95}
# MSE: 0.0046, RMSE: 0.0678, MAE:0.046156, R²: 0.8565
# Params: {'learning_rate': 0.05, 'max_depth': 9, 'max_features': 'sqrt', 'n_estimators': 150, 'subsample': 0.95}
# Mean Test R²: 0.8300328358761104
# Mean Test Neg MSE: -0.006206528809305087
# Std Test R²: 0.05153137936613633
# Std Test Neg MSE: 0.001814081209646177
# --------------------------------------------------
# Params: {'learning_rate': 0.05, 'max_depth': 9, 'max_features': 'sqrt', 'n_estimators': 200, 'subsample': 0.95}
# Mean Test R²: 0.8295687972675271
# Mean Test Neg MSE: -0.006225528867982994
# Std Test R²: 0.05181672051023912
# Std Test Neg MSE: 0.0018320247252418655
# --------------------------------------------------
# Params: {'learning_rate': 0.05, 'max_depth': 7, 'max_features': 'sqrt', 'n_estimators': 200, 'subsample': 0.95}
# Mean Test R²: 0.8263873194297071
# Mean Test Neg MSE: -0.006350629233266317
# Std Test R²: 0.04810613858303192
# Std Test Neg MSE: 0.001705218410462288
# --------------------------------------------------
# Params: {'learning_rate': 0.05, 'max_depth': 7, 'max_features': 'sqrt', 'n_estimators': 150, 'subsample': 0.95}
# Mean Test R²: 0.8256787771150801
# Mean Test Neg MSE: -0.006379386482771964
# Std Test R²: 0.04762404018764478
# Std Test Neg MSE: 0.0016879092965271427
# --------------------------------------------------
# Params: {'learning_rate': 0.05, 'max_depth': 7, 'max_features': 'sqrt', 'n_estimators': 150, 'subsample': 0.9}
# Mean Test R²: 0.8245237253163381
# Mean Test Neg MSE: -0.0064260511238260045
# Std Test R²: 0.042076984333468674
# Std Test Neg MSE: 0.001473740754542582
# --------------------------------------------------
# Params: {'learning_rate': 0.05, 'max_depth': 7, 'max_features': 'sqrt', 'n_estimators': 200, 'subsample': 0.9}
# Mean Test R²: 0.8243960280329043
# Mean Test Neg MSE: -0.006431839342847511
# Std Test R²: 0.04266034765505458
# Std Test Neg MSE: 0.001503848898337096
# --------------------------------------------------
# Params: {'learning_rate': 0.05, 'max_depth': 9, 'max_features': 'sqrt', 'n_estimators': 150, 'subsample': 0.97}
# Mean Test R²: 0.823923110075888
# Mean Test Neg MSE: -0.006425161534468056
# Std Test R²: 0.05272526502840111
# Std Test Neg MSE: 0.0018371584691293866
# --------------------------------------------------
# Params: {'learning_rate': 0.05, 'max_depth': 9, 'max_features': 'sqrt', 'n_estimators': 200, 'subsample': 0.97}
# Mean Test R²: 0.8238439847866419
# Mean Test Neg MSE: -0.006428338959513792
# Std Test R²: 0.0527846988919159
# Std Test Neg MSE: 0.001841835585821371
# --------------------------------------------------
# Params: {'learning_rate': 0.05, 'max_depth': 7, 'max_features': 'log2', 'n_estimators': 200, 'subsample': 0.95}
# Mean Test R²: 0.8237621719153628
# Mean Test Neg MSE: -0.006428654490353744
# Std Test R²: 0.05147094339865842
# Std Test Neg MSE: 0.0017399076757263093
# --------------------------------------------------
# Params: {'learning_rate': 0.05, 'max_depth': 9, 'max_features': 'log2', 'n_estimators': 150, 'subsample': 1.0}
# Mean Test R²: 0.8235333408843273
# Mean Test Neg MSE: -0.0064300414644601536
# Std Test R²: 0.05304203493260884
# Std Test Neg MSE: 0.0017945232692066404
# --------------------------------------------------
# Best Cross-Validation R² for pce: 0.8300328358761104
# Best Cross-Validation neg_mean_squared_error for pce: 0.006206528809305087
# Best parameters via GridSearchCV for pce: {'learning_rate': 0.05, 'max_depth': 9, 'max_features': 'sqrt', 'n_estimators': 150, 'subsample': 0.95}
