# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data.csv')  # read csv
X = data.iloc[:, :27]  # X feature

# %% [markdown]
# ### **J_sc**

# %%
# 1. data split
X_jsc = data.iloc[:, :27]  # X feature
y_jsc = data['Jsc']  # target feature
X_jsc_train, X_jsc_test, y_jsc_train, y_jsc_test = train_test_split(X_jsc, y_jsc, test_size=0.2, random_state=42)

# 2. DT model
# parameter grid
param_grid_jsc = {
    'max_depth': [20, 50, 100, 200],
    'min_samples_split': [7, 10, 13,15],
    'max_features': [None],
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'] 
}

# Initialize Desicion_tree regressor
dt_reg = DecisionTreeRegressor(random_state=42)

# 3. Grid searching for jsc
grid_jsc_search = GridSearchCV(
    estimator=dt_reg,
    param_grid=param_grid_jsc,
    cv=5,
    scoring= {'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R ²
    n_jobs=-1
)

grid_jsc_search.fit(X_jsc_train, y_jsc_train)

# Best model for jsc
best_dt_reg_jsc = grid_jsc_search.best_estimator_

# 4. Model evaluation on test set for jsc
y_jsc_pred = best_dt_reg_jsc.predict(X_jsc_test)
mse_jsc = mean_squared_error(y_jsc_test, y_jsc_pred)
rmse_jsc = mse_jsc**0.5
mae_jsc = mean_absolute_error(y_jsc_test, y_jsc_pred)
r2_jsc = r2_score(y_jsc_test, y_jsc_pred)

print(f"Best Parameters for jsc: {grid_jsc_search.best_params_}")
print(f"MSE: {mse_jsc:.4f}, RMSE: {rmse_jsc:.4f}, R²: {r2_jsc:.4f}, MAE:{mae_jsc}")

# 5. Get cross-validation results for jsc
cv_jsc_results_df = pd.DataFrame(grid_jsc_search.cv_results_)
cv_jsc_results_df = cv_jsc_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for jsc
best_cv_jsc_score_r2 = grid_jsc_search.best_score_
best_cv_jsc_score_neg_mse = -grid_jsc_search.cv_results_['mean_test_neg_mse'][grid_jsc_search.best_index_]

for index, row in cv_jsc_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for jsc: {best_cv_jsc_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for jsc: {best_cv_jsc_score_neg_mse}")
print(f"Best parameters via GridSearchCV for jsc: {grid_jsc_search.best_params_}")


# 6. Visualization for jsc
plt.scatter(y_jsc_test, y_jsc_pred, alpha=0.5)
plt.plot([y_jsc_test.min(), y_jsc_test.max()], [y_jsc_test.min(), y_jsc_test.max()], 'r--')
plt.xlabel('True jsc')
plt.ylabel('Predicted jsc')
plt.title('True vs. Predicted jsc')
plt.show()
# Out:
# Best Parameters for jsc: {'criterion': 'squared_error', 'max_depth': 50, 'max_features': None, 'min_samples_split': 13}
# MSE: 0.0084, RMSE: 0.0916, R²: 0.7411, MAE:0.04654254853790784
# Params: {'criterion': 'squared_error', 'max_depth': 100, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.7688863511916202
# Mean Test Neg MSE: -0.007797070015052662
# Std Test R²: 0.046970180151199144
# Std Test Neg MSE: 0.0020371698810617974
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 50, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.7688863511916202
# Mean Test Neg MSE: -0.007797070015052662
# Std Test R²: 0.046970180151199144
# Std Test Neg MSE: 0.0020371698810617974
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 200, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.7688863511916202
# Mean Test Neg MSE: -0.007797070015052662
# Std Test R²: 0.046970180151199144
# Std Test Neg MSE: 0.0020371698810617974
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 20, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.7677025790442661
# Mean Test Neg MSE: -0.007854433686726182
# Std Test R²: 0.055130993672921486
# Std Test Neg MSE: 0.002252401319338038
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 200, 'max_features': None, 'min_samples_split': 15}
# Mean Test R²: 0.7629294369397301
# Mean Test Neg MSE: -0.008028293939694727
# Std Test R²: 0.05874808661348645
# Std Test Neg MSE: 0.002466348626070013
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 50, 'max_features': None, 'min_samples_split': 15}
# Mean Test R²: 0.7629294369397301
# Mean Test Neg MSE: -0.008028293939694727
# Std Test R²: 0.05874808661348645
# Std Test Neg MSE: 0.002466348626070013
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 100, 'max_features': None, 'min_samples_split': 15}
# Mean Test R²: 0.7629294369397301
# Mean Test Neg MSE: -0.008028293939694727
# Std Test R²: 0.05874808661348645
# Std Test Neg MSE: 0.002466348626070013
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 20, 'max_features': None, 'min_samples_split': 15}
# Mean Test R²: 0.7618556278312634
# Mean Test Neg MSE: -0.008057785291633217
# Std Test R²: 0.057918083845914646
# Std Test Neg MSE: 0.0024364893535794023
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 200, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.7588623328071648
# Mean Test Neg MSE: -0.008097467191375659
# Std Test R²: 0.03820970029105069
# Std Test Neg MSE: 0.0017599367311997372
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.7588623328071648
# Mean Test Neg MSE: -0.008097467191375659
# Std Test R²: 0.03820970029105069
# Std Test Neg MSE: 0.0017599367311997372
# --------------------------------------------------
# Best Cross-Validation R² for jsc: 0.7688863511916202
# Best Cross-Validation neg_mean_squared_error for jsc: 0.007797070015052662
# Best parameters via GridSearchCV for jsc: {'criterion': 'squared_error', 'max_depth': 50, 'max_features': None, 'min_samples_split': 13}

# %% [markdown]
# ### **V_oc**

# %%
# 1. data split
X_voc = data.iloc[:, :27]  # X feature
y_voc = data['Voc']  # target feature
X_voc_train, X_voc_test, y_voc_train, y_voc_test = train_test_split(X_voc, y_voc, test_size=0.2, random_state=42)

# 2. DT model
# parameter grid
param_grid_voc = {
    'max_depth': [20, 50, 100, 200],
    'min_samples_split': [7, 10, 13, 15],
    'max_features': [None],
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson']
}

# Initialize Decision_tree regressor
dt_reg_voc = DecisionTreeRegressor(random_state=42)

# 3. Grid searching for voc
grid_voc_search = GridSearchCV(
    estimator=dt_reg_voc,
    param_grid=param_grid_voc,
    cv=5,
    scoring={'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R²
    n_jobs=-1
)

grid_voc_search.fit(X_voc_train, y_voc_train)

# Best model for voc
best_dt_reg_voc = grid_voc_search.best_estimator_

# 4. Model evaluation on test set for voc
y_voc_pred = best_dt_reg_voc.predict(X_voc_test)
mse_voc = mean_squared_error(y_voc_test, y_voc_pred)
rmse_voc = mse_voc**0.5
mae_voc = mean_absolute_error(y_voc_test, y_voc_pred)
r2_voc = r2_score(y_voc_test, y_voc_pred)

print(f"Best Parameters for voc: {grid_voc_search.best_params_}")
print(f"MSE: {mse_voc:.4f}, RMSE: {rmse_voc:.4f}, R²: {r2_voc:.4f}, MAE:{mae_voc}")

# 5. Get cross-validation results for voc
cv_voc_results_df = pd.DataFrame(grid_voc_search.cv_results_)
cv_voc_results_df = cv_voc_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for voc
best_cv_voc_score_r2 = grid_voc_search.best_score_
best_cv_voc_score_neg_mse = -grid_voc_search.cv_results_['mean_test_neg_mse'][grid_voc_search.best_index_]

for index, row in cv_voc_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for voc: {best_cv_voc_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for voc: {best_cv_voc_score_neg_mse}")
print(f"Best parameters via GridSearchCV for voc: {grid_voc_search.best_params_}")

# 6. Visualization for voc
plt.scatter(y_voc_test, y_voc_pred, alpha=0.5)
plt.plot([y_voc_test.min(), y_voc_test.max()], [y_voc_test.min(), y_voc_test.max()], 'r--')
plt.xlabel('True voc')
plt.ylabel('Predicted voc')
plt.title('True vs. Predicted voc')
plt.show()
# Out:
# Best Parameters for voc: {'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': None, 'min_samples_split': 13}
# MSE: 0.0021, RMSE: 0.0461, R²: 0.9506, MAE:0.02729331369973525
# Params: {'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.8223488633964834
# Mean Test Neg MSE: -0.007186626895274472
# Std Test R²: 0.05504790769770754
# Std Test Neg MSE: 0.0021376101919840834
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 50, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.8217533993725802
# Mean Test Neg MSE: -0.007204800507523039
# Std Test R²: 0.05542316172864535
# Std Test Neg MSE: 0.002131712909980807
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 200, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.8217533993725802
# Mean Test Neg MSE: -0.007204800507523039
# Std Test R²: 0.05542316172864535
# Std Test Neg MSE: 0.002131712909980807
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 100, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.8217533993725802
# Mean Test Neg MSE: -0.007204800507523039
# Std Test R²: 0.05542316172864535
# Std Test Neg MSE: 0.002131712909980807
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 50, 'max_features': None, 'min_samples_split': 7}
# Mean Test R²: 0.8217517742483424
# Mean Test Neg MSE: -0.007220494769214247
# Std Test R²: 0.050778660464079
# Std Test Neg MSE: 0.0019508718848699539
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 100, 'max_features': None, 'min_samples_split': 7}
# Mean Test R²: 0.8217517742483424
# Mean Test Neg MSE: -0.007220494769214247
# Std Test R²: 0.050778660464079
# Std Test Neg MSE: 0.0019508718848699539
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 200, 'max_features': None, 'min_samples_split': 7}
# Mean Test R²: 0.8217517742483424
# Mean Test Neg MSE: -0.007220494769214247
# Std Test R²: 0.050778660464079
# Std Test Neg MSE: 0.0019508718848699539
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 20, 'max_features': None, 'min_samples_split': 7}
# Mean Test R²: 0.8215627591330963
# Mean Test Neg MSE: -0.007228756170418298
# Std Test R²: 0.05079695439092168
# Std Test Neg MSE: 0.001954091338414004
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 20, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.8207525504451236
# Mean Test Neg MSE: -0.00725663148175767
# Std Test R²: 0.05165301755890464
# Std Test Neg MSE: 0.0019871889522825098
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 200, 'max_features': None, 'min_samples_split': 15}
# Mean Test R²: 0.8205222097396814
# Mean Test Neg MSE: -0.007234907216955312
# Std Test R²: 0.05576242128544281
# Std Test Neg MSE: 0.0020677434135674597
# --------------------------------------------------
# Best Cross-Validation R² for voc: 0.8223488633964834
# Best Cross-Validation neg_mean_squared_error for voc: 0.007186626895274472
# Best parameters via GridSearchCV for voc: {'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': None, 'min_samples_split': 13}

# %% [markdown]
# ### **FF**

# %%
# 1. data split
X_ff = data.iloc[:, :27]  # X feature
y_ff = data['FF']  # target feature
X_ff_train, X_ff_test, y_ff_train, y_ff_test = train_test_split(X_ff, y_ff, test_size=0.2, random_state=42)

# 2. DT model
# parameter grid
param_grid_ff = {
    'max_depth': [None, 10,  30, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2'],
    'max_leaf_nodes': [None, 10, 20, 30],
    'min_impurity_decrease': [0.0, 0.01, 0.02]
}
# Initialize Decision_tree regressor
dt_reg_ff = DecisionTreeRegressor(random_state=42)

# 3. Grid searching for ff
grid_ff_search = GridSearchCV(
    estimator=dt_reg_ff,
    param_grid=param_grid_ff,
    cv=5,
    scoring={'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R²
    n_jobs=-1
)

grid_ff_search.fit(X_ff_train, y_ff_train)

# Best model for ff
best_dt_reg_ff = grid_ff_search.best_estimator_

# 4. Model evaluation on test set for ff
y_ff_pred = best_dt_reg_ff.predict(X_ff_test)
mse_ff = mean_squared_error(y_ff_test, y_ff_pred)
rmse_ff = mse_ff**0.5
mae_ff = mean_absolute_error(y_ff_test, y_ff_pred)
r2_ff = r2_score(y_ff_test, y_ff_pred)

print(f"Best Parameters for ff: {grid_ff_search.best_params_}")
print(f"MSE: {mse_ff:.4f}, RMSE: {rmse_ff:.4f}, R²: {r2_ff:.4f}, MAE:{mae_ff}")

# 5. Get cross-validation results for ff
cv_ff_results_df = pd.DataFrame(grid_ff_search.cv_results_)
cv_ff_results_df = cv_ff_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for ff
best_cv_ff_score_r2 = grid_ff_search.best_score_
best_cv_ff_score_neg_mse = -grid_ff_search.cv_results_['mean_test_neg_mse'][grid_ff_search.best_index_]

for index, row in cv_ff_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for ff: {best_cv_ff_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for ff: {best_cv_ff_score_neg_mse}")
print(f"Best parameters via GridSearchCV for ff: {grid_ff_search.best_params_}")

# 6. Visualization for ff
plt.scatter(y_ff_test, y_ff_pred, alpha=0.5)
plt.plot([y_ff_test.min(), y_ff_test.max()], [y_ff_test.min(), y_ff_test.max()], 'r--')
plt.xlabel('True ff')
plt.ylabel('Predicted ff')
plt.title('True vs. Predicted ff')
plt.show()
# Out:
# Best Parameters for ff: {'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 2}
# MSE: 0.0142, RMSE: 0.1190, R²: 0.2795, MAE:0.06834342448894698
# Params: {'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Mean Test R²: 0.4107900545130372
# Mean Test Neg MSE: -0.010016634123006029
# Std Test R²: 0.17064521907594327
# Std Test Neg MSE: 0.004082158434818161
# --------------------------------------------------
# Params: {'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Mean Test R²: 0.4107900545130372
# Mean Test Neg MSE: -0.010016634123006029
# Std Test R²: 0.17064521907594327
# Std Test Neg MSE: 0.004082158434818161
# --------------------------------------------------
# Params: {'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Mean Test R²: 0.4082612067830215
# Mean Test Neg MSE: -0.01002447708151772
# Std Test R²: 0.09428430869788716
# Std Test Neg MSE: 0.0028226273336639045
# --------------------------------------------------
# Params: {'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Mean Test R²: 0.39647005300407
# Mean Test Neg MSE: -0.010431883463650501
# Std Test R²: 0.07493757970986803
# Std Test Neg MSE: 0.0030031635793274754
# --------------------------------------------------
# Params: {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Mean Test R²: 0.3719070056426276
# Mean Test Neg MSE: -0.010682416052652665
# Std Test R²: 0.12118576800895692
# Std Test Neg MSE: 0.003163657632612828
# --------------------------------------------------
# Params: {'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 8, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Mean Test R²: 0.3301519708129736
# Mean Test Neg MSE: -0.011313828679130616
# Std Test R²: 0.1165474885212942
# Std Test Neg MSE: 0.00321427813613432
# --------------------------------------------------
# Params: {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 8, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Mean Test R²: 0.3301519708129736
# Mean Test Neg MSE: -0.011313828679130616
# Std Test R²: 0.1165474885212942
# Std Test Neg MSE: 0.00321427813613432
# --------------------------------------------------
# Params: {'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 8, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Mean Test R²: 0.3301519708129736
# Mean Test Neg MSE: -0.011313828679130616
# Std Test R²: 0.1165474885212942
# Std Test Neg MSE: 0.00321427813613432
# --------------------------------------------------
# Params: {'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': 8, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Mean Test R²: 0.3301519708129736
# Mean Test Neg MSE: -0.011313828679130616
# Std Test R²: 0.1165474885212942
# Std Test Neg MSE: 0.00321427813613432
# --------------------------------------------------
# Params: {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 8, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Mean Test R²: 0.3301519708129736
# Mean Test Neg MSE: -0.011313828679130616
# Std Test R²: 0.1165474885212942
# Std Test Neg MSE: 0.00321427813613432
# --------------------------------------------------
# Best Cross-Validation R² for ff: 0.4107900545130372
# Best Cross-Validation neg_mean_squared_error for ff: 0.010016634123006029
# Best parameters via GridSearchCV for ff: {'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 2}

# %% [markdown]
# ### **PCE**

# %%
# 1. data split
X_pce = data.iloc[:, :27]  # X feature
y_pce = data['PCE']  # target feature
X_pce_train, X_pce_test, y_pce_train, y_pce_test = train_test_split(X_pce, y_pce, test_size=0.2, random_state=42)

# 2. DT model
# parameter grid
param_grid_pce = {
    'max_depth': [5, 10, 20],
    'min_samples_leaf': [2, 4, 8],
    'max_features': [None, 'sqrt', 'log2'],
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson']
}

# Initialize Decision_tree regressor
dt_reg_pce = DecisionTreeRegressor(random_state=42)

# 3. Grid searching for pce
grid_pce_search = GridSearchCV(
    estimator=dt_reg_pce,
    param_grid=param_grid_pce,
    cv=5,
    scoring={'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R²
    n_jobs=-1
)

grid_pce_search.fit(X_pce_train, y_pce_train)

# Best model for pce
best_dt_reg_pce = grid_pce_search.best_estimator_

# 4. Model evaluation on test set for pce
y_pce_pred = best_dt_reg_pce.predict(X_pce_test)
mse_pce = mean_squared_error(y_pce_test, y_pce_pred)
rmse_pce = mse_pce**0.5
mae_pce = mean_absolute_error(y_pce_test, y_pce_pred)
r2_pce = r2_score(y_pce_test, y_pce_pred)

print(f"Best Parameters for pce: {grid_pce_search.best_params_}")
print(f"MSE: {mse_pce:.4f}, RMSE: {rmse_pce:.4f}, MAE:{mae_pce:4f}, R²: {r2_pce:.4f} ")

# 5. Get cross-validation results for pce
cv_pce_results_df = pd.DataFrame(grid_pce_search.cv_results_)
cv_pce_results_df = cv_pce_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for pce
best_cv_pce_score_r2 = grid_pce_search.best_score_
best_cv_pce_score_neg_mse = -grid_pce_search.cv_results_['mean_test_neg_mse'][grid_pce_search.best_index_]

for index, row in cv_pce_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for pce: {best_cv_pce_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for pce: {best_cv_pce_score_neg_mse}")
print(f"Best parameters via GridSearchCV for pce: {grid_pce_search.best_params_}")

# 6. Visualization for pce
plt.scatter(y_pce_test, y_pce_pred, alpha=0.5)
plt.plot([y_pce_test.min(), y_pce_test.max()], [y_pce_test.min(), y_pce_test.max()], 'r--')
plt.xlabel('True PCE (%)')
plt.ylabel('Predicted PCE (%)')
plt.title('True vs. Predicted PCE (%)')
plt.show()
# Out:
# Best Parameters for pce: {'criterion': 'squared_error', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2}
# MSE: 0.0153, RMSE: 0.1235, MAE:0.071034, R²: 0.5949
# Params: {'criterion': 'squared_error', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2}
# Mean Test R²: 0.7341952491510566
# Mean Test Neg MSE: -0.009934497251272694
# Std Test R²: 0.027797091357333673
# Std Test Neg MSE: 0.0009034435083773504
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2}
# Mean Test R²: 0.7315119194489252
# Mean Test Neg MSE: -0.009956322632899124
# Std Test R²: 0.03849076514331767
# Std Test Neg MSE: 0.0004185962800455647
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 4}
# Mean Test R²: 0.7210855482232537
# Mean Test Neg MSE: -0.010452856655827921
# Std Test R²: 0.05925754069485543
# Std Test Neg MSE: 0.002361478659239679
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 4}
# Mean Test R²: 0.7209882788071098
# Mean Test Neg MSE: -0.010454173599298382
# Std Test R²: 0.06069432122180309
# Std Test Neg MSE: 0.0024095141353465853
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 4}
# Mean Test R²: 0.7121423470797893
# Mean Test Neg MSE: -0.010788677973475358
# Std Test R²: 0.040004828427957564
# Std Test Neg MSE: 0.0016739916827280103
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 4}
# Mean Test R²: 0.7073073485950928
# Mean Test Neg MSE: -0.01093973471549528
# Std Test R²: 0.04627346374824877
# Std Test Neg MSE: 0.0017510249542966704
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 4}
# Mean Test R²: 0.7058799483268867
# Mean Test Neg MSE: -0.01098473293023267
# Std Test R²: 0.052564498725002795
# Std Test Neg MSE: 0.0018684997336038164
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2}
# Mean Test R²: 0.7019970759951984
# Mean Test Neg MSE: -0.010884304618675683
# Std Test R²: 0.07832975154873517
# Std Test Neg MSE: 0.0015098430232502603
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 4}
# Mean Test R²: 0.6982967883788473
# Mean Test Neg MSE: -0.011243974576211551
# Std Test R²: 0.053216258948640224
# Std Test Neg MSE: 0.0017812531692692772
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4}
# Mean Test R²: 0.6978203351657821
# Mean Test Neg MSE: -0.01123709351971574
# Std Test R²: 0.04981121877416256
# Std Test Neg MSE: 0.001340511799523208
# --------------------------------------------------
# Best Cross-Validation R² for pce: 0.7341952491510566
# Best Cross-Validation neg_mean_squared_error for pce: 0.009934497251272694
# Best parameters via GridSearchCV for pce: {'criterion': 'squared_error', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2}

# %%
pd.options.display.max_rows = None
cv_pce_results_df['mean_test_r2']
# Out:
# 1    0.673471
# 2    0.659212
# 3    0.643560
# 4    0.643560
# 0    0.571150
# Name: mean_test_r2, dtype: float64
