# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data.csv')  # read csv
X = data.iloc[:, :26]  # X feature

# %% [markdown]
# ### **J_sc**

# %%
# 1. data split
X_jsc = data.iloc[:, :26]  # X feature
y_jsc = data['Jsc (mA/cm2)']  # target feature
X_jsc_train, X_jsc_test, y_jsc_train, y_jsc_test = train_test_split(X_jsc, y_jsc, test_size=0.2, random_state=42)

# 2. DT model
# parameter grid
param_grid_jsc = {
    'max_depth': [7, 10, 13, 15, 18, 20],
    'min_samples_split': [7, 10, 13,15],
    'max_features': [None],
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'] 
}

# Initialize Desicion_tree regressor
dt_reg = DecisionTreeRegressor(random_state=42)

# 3. Grid searching for jsc
grid_jsc_search = GridSearchCV(
    estimator=dt_reg,
    param_grid=param_grid_jsc,
    cv=5,
    scoring= {'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R ²
    n_jobs=-1
)

grid_jsc_search.fit(X_jsc_train, y_jsc_train)

# Best model for jsc
best_dt_reg_jsc = grid_jsc_search.best_estimator_

# 4. Model evaluation on test set for jsc
y_jsc_pred = best_dt_reg_jsc.predict(X_jsc_test)
mse_jsc = mean_squared_error(y_jsc_test, y_jsc_pred)
rmse_jsc = mse_jsc**0.5
mae_jsc = mean_absolute_error(y_jsc_test, y_jsc_pred)
r2_jsc = r2_score(y_jsc_test, y_jsc_pred)

print(f"Best Parameters for jsc: {grid_jsc_search.best_params_}")
print(f"MSE: {mse_jsc:.4f}, RMSE: {rmse_jsc:.4f}, R²: {r2_jsc:.4f}, MAE:{mae_jsc}")

# 5. Get cross-validation results for jsc
cv_jsc_results_df = pd.DataFrame(grid_jsc_search.cv_results_)
cv_jsc_results_df = cv_jsc_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for jsc
best_cv_jsc_score_r2 = grid_jsc_search.best_score_
best_cv_jsc_score_neg_mse = -grid_jsc_search.cv_results_['mean_test_neg_mse'][grid_jsc_search.best_index_]

for index, row in cv_jsc_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for jsc: {best_cv_jsc_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for jsc: {best_cv_jsc_score_neg_mse}")
print(f"Best parameters via GridSearchCV for jsc: {grid_jsc_search.best_params_}")


# 6. Visualization for jsc
plt.scatter(y_jsc_test, y_jsc_pred, alpha=0.5)
plt.plot([y_jsc_test.min(), y_jsc_test.max()], [y_jsc_test.min(), y_jsc_test.max()], 'r--')
plt.xlabel('True jsc')
plt.ylabel('Predicted jsc')
plt.title('True vs. Predicted jsc')
plt.show()
# Out:
# Best Parameters for jsc: {'criterion': 'absolute_error', 'max_depth': 20, 'max_features': None, 'min_samples_split': 10}
# MSE: 0.0065, RMSE: 0.0805, R²: 0.8180, MAE:0.04323469386734694
# Params: {'criterion': 'absolute_error', 'max_depth': 20, 'max_features': None, 'min_samples_split': 10}
# Mean Test R²: 0.7791167968760844
# Mean Test Neg MSE: -0.007660319387218258
# Std Test R²: 0.06332666288553924
# Std Test Neg MSE: 0.002495981462473921
# --------------------------------------------------
# Params: {'criterion': 'absolute_error', 'max_depth': 15, 'max_features': None, 'min_samples_split': 10}
# Mean Test R²: 0.7744780400193412
# Mean Test Neg MSE: -0.007837314658831722
# Std Test R²: 0.05572216098148676
# Std Test Neg MSE: 0.002369129464568603
# --------------------------------------------------
# Params: {'criterion': 'absolute_error', 'max_depth': 10, 'max_features': None, 'min_samples_split': 10}
# Mean Test R²: 0.7708874746002717
# Mean Test Neg MSE: -0.00795078993726912
# Std Test R²: 0.04796498693101384
# Std Test Neg MSE: 0.0020857522787568693
# --------------------------------------------------
# Params: {'criterion': 'absolute_error', 'max_depth': 13, 'max_features': None, 'min_samples_split': 10}
# Mean Test R²: 0.7567602072463095
# Mean Test Neg MSE: -0.008443330772501558
# Std Test R²: 0.05901866468941475
# Std Test Neg MSE: 0.0024794002454725157
# --------------------------------------------------
# Params: {'criterion': 'absolute_error', 'max_depth': 18, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.7567429887097674
# Mean Test Neg MSE: -0.008439833992836302
# Std Test R²: 0.05568851551488136
# Std Test Neg MSE: 0.002408651105113872
# --------------------------------------------------
# Params: {'criterion': 'absolute_error', 'max_depth': 18, 'max_features': None, 'min_samples_split': 10}
# Mean Test R²: 0.7562232239698443
# Mean Test Neg MSE: -0.008437869702073634
# Std Test R²: 0.05338808932616803
# Std Test Neg MSE: 0.0021509411707976525
# --------------------------------------------------
# Params: {'criterion': 'absolute_error', 'max_depth': 20, 'max_features': None, 'min_samples_split': 15}
# Mean Test R²: 0.7526535603708878
# Mean Test Neg MSE: -0.008585883033039244
# Std Test R²: 0.07038612362781224
# Std Test Neg MSE: 0.0028732018095399387
# --------------------------------------------------
# Params: {'criterion': 'absolute_error', 'max_depth': 18, 'max_features': None, 'min_samples_split': 15}
# Mean Test R²: 0.7512799354374113
# Mean Test Neg MSE: -0.008635501123870147
# Std Test R²: 0.07136201603654707
# Std Test Neg MSE: 0.002911761332831294
# --------------------------------------------------
# Params: {'criterion': 'absolute_error', 'max_depth': 20, 'max_features': None, 'min_samples_split': 7}
# Mean Test R²: 0.7485084130085494
# Mean Test Neg MSE: -0.008673258807333464
# Std Test R²: 0.051398609318314074
# Std Test Neg MSE: 0.002169905597390796
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 7, 'max_features': None, 'min_samples_split': 10}
# Mean Test R²: 0.7465945259996383
# Mean Test Neg MSE: -0.008668472775919044
# Std Test R²: 0.03303992995703181
# Std Test Neg MSE: 0.0011882925127886645
# --------------------------------------------------
# Best Cross-Validation R² for jsc: 0.7791167968760844
# Best Cross-Validation neg_mean_squared_error for jsc: 0.007660319387218258
# Best parameters via GridSearchCV for jsc: {'criterion': 'absolute_error', 'max_depth': 20, 'max_features': None, 'min_samples_split': 10}

# %% [markdown]
# ### **V_oc**

# %%
# 1. data split
X_voc = data.iloc[:, :26]  # X feature
y_voc = data['Voc (V)']  # target feature
X_voc_train, X_voc_test, y_voc_train, y_voc_test = train_test_split(X_voc, y_voc, test_size=0.2, random_state=42)

# 2. DT model
# parameter grid
param_grid_voc = {
    'max_depth': [7, 10, 13, 15, 18, 20],
    'min_samples_split': [7, 10, 13, 15],
    'max_features': [None],
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson']
}

# Initialize Decision_tree regressor
dt_reg_voc = DecisionTreeRegressor(random_state=42)

# 3. Grid searching for voc
grid_voc_search = GridSearchCV(
    estimator=dt_reg_voc,
    param_grid=param_grid_voc,
    cv=5,
    scoring={'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R²
    n_jobs=-1
)

grid_voc_search.fit(X_voc_train, y_voc_train)

# Best model for voc
best_dt_reg_voc = grid_voc_search.best_estimator_

# 4. Model evaluation on test set for voc
y_voc_pred = best_dt_reg_voc.predict(X_voc_test)
mse_voc = mean_squared_error(y_voc_test, y_voc_pred)
rmse_voc = mse_voc**0.5
mae_voc = mean_absolute_error(y_voc_test, y_voc_pred)
r2_voc = r2_score(y_voc_test, y_voc_pred)

print(f"Best Parameters for voc: {grid_voc_search.best_params_}")
print(f"MSE: {mse_voc:.4f}, RMSE: {rmse_voc:.4f}, R²: {r2_voc:.4f}, MAE:{mae_voc}")

# 5. Get cross-validation results for voc
cv_voc_results_df = pd.DataFrame(grid_voc_search.cv_results_)
cv_voc_results_df = cv_voc_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for voc
best_cv_voc_score_r2 = grid_voc_search.best_score_
best_cv_voc_score_neg_mse = -grid_voc_search.cv_results_['mean_test_neg_mse'][grid_voc_search.best_index_]

for index, row in cv_voc_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for voc: {best_cv_voc_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for voc: {best_cv_voc_score_neg_mse}")
print(f"Best parameters via GridSearchCV for voc: {grid_voc_search.best_params_}")

# 6. Visualization for voc
plt.scatter(y_voc_test, y_voc_pred, alpha=0.5)
plt.plot([y_voc_test.min(), y_voc_test.max()], [y_voc_test.min(), y_voc_test.max()], 'r--')
plt.xlabel('True voc')
plt.ylabel('Predicted voc')
plt.title('True vs. Predicted voc')
plt.show()
# Out:
# Best Parameters for voc: {'criterion': 'poisson', 'max_depth': 7, 'max_features': None, 'min_samples_split': 13}
# MSE: 0.0130, RMSE: 0.1138, R²: 0.8573, MAE:0.06756102866749669
# Params: {'criterion': 'poisson', 'max_depth': 7, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.8851784121425222
# Mean Test Neg MSE: -0.009345855715140215
# Std Test R²: 0.038577997633282485
# Std Test Neg MSE: 0.0025902465645631857
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 7, 'max_features': None, 'min_samples_split': 10}
# Mean Test R²: 0.8804554333932078
# Mean Test Neg MSE: -0.009718642536360211
# Std Test R²: 0.04736003177881548
# Std Test Neg MSE: 0.0032665738663779573
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 20, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.8792132970011124
# Mean Test Neg MSE: -0.009874221872012456
# Std Test R²: 0.052164501612285
# Std Test Neg MSE: 0.0039917279008529075
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 15, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.8771061925903115
# Mean Test Neg MSE: -0.010049316181792362
# Std Test R²: 0.05496341778695205
# Std Test Neg MSE: 0.00423704183891494
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 10, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.8761064358110315
# Mean Test Neg MSE: -0.010111269174626
# Std Test R²: 0.048837598527053716
# Std Test Neg MSE: 0.0036429584578732996
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 18, 'max_features': None, 'min_samples_split': 13}
# Mean Test R²: 0.8756305807537803
# Mean Test Neg MSE: -0.010150160275779049
# Std Test R²: 0.04792115032633
# Std Test Neg MSE: 0.0035737182633855486
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 7, 'max_features': None, 'min_samples_split': 7}
# Mean Test R²: 0.871537416210176
# Mean Test Neg MSE: -0.010409742845732381
# Std Test R²: 0.05352036803818967
# Std Test Neg MSE: 0.003667068996195245
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 15, 'max_features': None, 'min_samples_split': 15}
# Mean Test R²: 0.871091442623559
# Mean Test Neg MSE: -0.010572159093754826
# Std Test R²: 0.04895472194125215
# Std Test Neg MSE: 0.003766041898760968
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 7, 'max_features': None, 'min_samples_split': 15}
# Mean Test R²: 0.8702055104091307
# Mean Test Neg MSE: -0.01074823358389776
# Std Test R²: 0.04044036542404644
# Std Test Neg MSE: 0.0034895961302000983
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 18, 'max_features': None, 'min_samples_split': 15}
# Mean Test R²: 0.869614596665742
# Mean Test Neg MSE: -0.01066767460801048
# Std Test R²: 0.047639669995145205
# Std Test Neg MSE: 0.003589096180860199
# --------------------------------------------------
# Best Cross-Validation R² for voc: 0.8851784121425222
# Best Cross-Validation neg_mean_squared_error for voc: 0.009345855715140215
# Best parameters via GridSearchCV for voc: {'criterion': 'poisson', 'max_depth': 7, 'max_features': None, 'min_samples_split': 13}

# %% [markdown]
# ### **FF**

# %%
# 1. data split
X_ff = data.iloc[:, :26]  # X feature
y_ff = data['FF']  # target feature
X_ff_train, X_ff_test, y_ff_train, y_ff_test = train_test_split(X_ff, y_ff, test_size=0.2, random_state=42)

# 2. DT model
# parameter grid
param_grid_ff = {
    'max_depth': [5, 10, 20],
    'min_samples_leaf': [2, 4, 8],
    'max_features': [None, 'sqrt', 'log2'],
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson']
}
# Initialize Decision_tree regressor
dt_reg_ff = DecisionTreeRegressor(random_state=42)

# 3. Grid searching for ff
grid_ff_search = GridSearchCV(
    estimator=dt_reg_ff,
    param_grid=param_grid_ff,
    cv=5,
    scoring={'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R²
    n_jobs=-1
)

grid_ff_search.fit(X_ff_train, y_ff_train)

# Best model for ff
best_dt_reg_ff = grid_ff_search.best_estimator_

# 4. Model evaluation on test set for ff
y_ff_pred = best_dt_reg_ff.predict(X_ff_test)
mse_ff = mean_squared_error(y_ff_test, y_ff_pred)
rmse_ff = mse_ff**0.5
mae_ff = mean_absolute_error(y_ff_test, y_ff_pred)
r2_ff = r2_score(y_ff_test, y_ff_pred)

print(f"Best Parameters for ff: {grid_ff_search.best_params_}")
print(f"MSE: {mse_ff:.4f}, RMSE: {rmse_ff:.4f}, R²: {r2_ff:.4f}, MAE:{mae_ff}")

# 5. Get cross-validation results for ff
cv_ff_results_df = pd.DataFrame(grid_ff_search.cv_results_)
cv_ff_results_df = cv_ff_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for ff
best_cv_ff_score_r2 = grid_ff_search.best_score_
best_cv_ff_score_neg_mse = -grid_ff_search.cv_results_['mean_test_neg_mse'][grid_ff_search.best_index_]

for index, row in cv_ff_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for ff: {best_cv_ff_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for ff: {best_cv_ff_score_neg_mse}")
print(f"Best parameters via GridSearchCV for ff: {grid_ff_search.best_params_}")

# 6. Visualization for ff
plt.scatter(y_ff_test, y_ff_pred, alpha=0.5)
plt.plot([y_ff_test.min(), y_ff_test.max()], [y_ff_test.min(), y_ff_test.max()], 'r--')
plt.xlabel('True ff')
plt.ylabel('Predicted ff')
plt.title('True vs. Predicted ff')
plt.show()
# Out:
# Best Parameters for ff: {'criterion': 'poisson', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 2}
# MSE: 0.0047, RMSE: 0.0687, R²: 0.4922, MAE:0.04887565863819648
# Params: {'criterion': 'poisson', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 2}
# Mean Test R²: 0.48457215135144366
# Mean Test Neg MSE: -0.005274391806437906
# Std Test R²: 0.06262169253824494
# Std Test Neg MSE: 0.0009264340786226666
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2}
# Mean Test R²: 0.47305596614981005
# Mean Test Neg MSE: -0.0053616315691457596
# Std Test R²: 0.07062935359751353
# Std Test Neg MSE: 0.0008383312665336366
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2}
# Mean Test R²: 0.47277603204624297
# Mean Test Neg MSE: -0.005364402269782703
# Std Test R²: 0.07068446581449289
# Std Test Neg MSE: 0.0008383034363004608
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 4}
# Mean Test R²: 0.46686618539989533
# Mean Test Neg MSE: -0.005601917186456008
# Std Test R²: 0.1163046637720201
# Std Test Neg MSE: 0.002046930486885924
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 4}
# Mean Test R²: 0.4651245307578689
# Mean Test Neg MSE: -0.005620545155565558
# Std Test R²: 0.11549892153891725
# Std Test Neg MSE: 0.002042215384502352
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 2}
# Mean Test R²: 0.46331136684838975
# Mean Test Neg MSE: -0.005489849020465604
# Std Test R²: 0.06478742107495554
# Std Test Neg MSE: 0.0009707505203303957
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 2}
# Mean Test R²: 0.46106032350306697
# Mean Test Neg MSE: -0.0054929397316416835
# Std Test R²: 0.09201367170651367
# Std Test Neg MSE: 0.001109327342777362
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 2}
# Mean Test R²: 0.459788865688021
# Mean Test Neg MSE: -0.005542610362297131
# Std Test R²: 0.05963282937021782
# Std Test Neg MSE: 0.0010000668308560372
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 4}
# Mean Test R²: 0.45750061976297796
# Mean Test Neg MSE: -0.005676865277276485
# Std Test R²: 0.10501891576655299
# Std Test Neg MSE: 0.0019130415642876712
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 4}
# Mean Test R²: 0.45501530402969587
# Mean Test Neg MSE: -0.00570957230336456
# Std Test R²: 0.10751910998765225
# Std Test Neg MSE: 0.0019620476863938664
# --------------------------------------------------
# Best Cross-Validation R² for ff: 0.48457215135144366
# Best Cross-Validation neg_mean_squared_error for ff: 0.005274391806437906
# Best parameters via GridSearchCV for ff: {'criterion': 'poisson', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 2}

# %% [markdown]
# ### **PCE**

# %%
# 1. data split
X_pce = data.iloc[:, :26]  # X feature
y_pce = data['PCE (%)']  # target feature
X_pce_train, X_pce_test, y_pce_train, y_pce_test = train_test_split(X_pce, y_pce, test_size=0.2, random_state=42)

# 2. DT model
# parameter grid
param_grid_pce = {
    'max_depth': [5, 10, 20],
    'min_samples_leaf': [2, 4, 8],
    'max_features': [None, 'sqrt', 'log2'],
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson']
}

# Initialize Decision_tree regressor
dt_reg_pce = DecisionTreeRegressor(random_state=42)

# 3. Grid searching for pce
grid_pce_search = GridSearchCV(
    estimator=dt_reg_pce,
    param_grid=param_grid_pce,
    cv=5,
    scoring={'r2': 'r2', 'neg_mse': 'neg_mean_squared_error'},  # two standard
    refit='r2',  # Select the best model based on R²
    n_jobs=-1
)

grid_pce_search.fit(X_pce_train, y_pce_train)

# Best model for pce
best_dt_reg_pce = grid_pce_search.best_estimator_

# 4. Model evaluation on test set for pce
y_pce_pred = best_dt_reg_pce.predict(X_pce_test)
mse_pce = mean_squared_error(y_pce_test, y_pce_pred)
rmse_pce = mse_pce**0.5
mae_pce = mean_absolute_error(y_pce_test, y_pce_pred)
r2_pce = r2_score(y_pce_test, y_pce_pred)

print(f"Best Parameters for pce: {grid_pce_search.best_params_}")
print(f"MSE: {mse_pce:.4f}, RMSE: {rmse_pce:.4f}, MAE:{mae_pce:4f}, R²: {r2_pce:.4f} ")

# 5. Get cross-validation results for pce
cv_pce_results_df = pd.DataFrame(grid_pce_search.cv_results_)
cv_pce_results_df = cv_pce_results_df.sort_values(by='mean_test_r2', ascending=False)  # sort by r^2

# Best CV score for pce
best_cv_pce_score_r2 = grid_pce_search.best_score_
best_cv_pce_score_neg_mse = -grid_pce_search.cv_results_['mean_test_neg_mse'][grid_pce_search.best_index_]

for index, row in cv_pce_results_df.head(10).iterrows():
    print(f"Params: {row['params']}")
    print(f"Mean Test R²: {row['mean_test_r2']}")
    print(f"Mean Test Neg MSE: {row['mean_test_neg_mse']}")
    print(f"Std Test R²: {row['std_test_r2']}")
    print(f"Std Test Neg MSE: {row['std_test_neg_mse']}")
    print("-" * 50)

print(f"Best Cross-Validation R² for pce: {best_cv_pce_score_r2}")
print(f"Best Cross-Validation neg_mean_squared_error for pce: {best_cv_pce_score_neg_mse}")
print(f"Best parameters via GridSearchCV for pce: {grid_pce_search.best_params_}")

# 6. Visualization for pce
plt.scatter(y_pce_test, y_pce_pred, alpha=0.5)
plt.plot([y_pce_test.min(), y_pce_test.max()], [y_pce_test.min(), y_pce_test.max()], 'r--')
plt.xlabel('True PCE (%)')
plt.ylabel('Predicted PCE (%)')
plt.title('True vs. Predicted PCE (%)')
plt.show()
# Out:
# Best Parameters for pce: {'criterion': 'poisson', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 2}
# MSE: 0.0068, RMSE: 0.0827, MAE:0.052217, R²: 0.7864
# Params: {'criterion': 'poisson', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 2}
# Mean Test R²: 0.7295016306541567
# Mean Test Neg MSE: -0.00991306529403881
# Std Test R²: 0.02589644810617373
# Std Test Neg MSE: 0.0011071496458077961
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 2}
# Mean Test R²: 0.7248376277914591
# Mean Test Neg MSE: -0.010023460865699397
# Std Test R²: 0.055222140819097834
# Std Test Neg MSE: 0.0017571063499246628
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 2}
# Mean Test R²: 0.722592179764287
# Mean Test Neg MSE: -0.010261569997694845
# Std Test R²: 0.01458667015914252
# Std Test Neg MSE: 0.0016590607330961688
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 2}
# Mean Test R²: 0.7220453195937941
# Mean Test Neg MSE: -0.010302144882074944
# Std Test R²: 0.014960501362241752
# Std Test Neg MSE: 0.0017972777595561722
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 2}
# Mean Test R²: 0.7208706162977517
# Mean Test Neg MSE: -0.010269659780641241
# Std Test R²: 0.013279722237873926
# Std Test Neg MSE: 0.0012592723971357063
# --------------------------------------------------
# Params: {'criterion': 'friedman_mse', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 2}
# Mean Test R²: 0.7149255814545228
# Mean Test Neg MSE: -0.010499846568282605
# Std Test R²: 0.01818890429641334
# Std Test Neg MSE: 0.0014565435486586064
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 4}
# Mean Test R²: 0.7079321516632359
# Mean Test Neg MSE: -0.010707659982536245
# Std Test R²: 0.0516488716497982
# Std Test Neg MSE: 0.0020588234774105325
# --------------------------------------------------
# Params: {'criterion': 'poisson', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 4}
# Mean Test R²: 0.7050842501970372
# Mean Test Neg MSE: -0.010778435121177928
# Std Test R²: 0.0630308477289844
# Std Test Neg MSE: 0.0022329080818902
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 2}
# Mean Test R²: 0.7040245839819288
# Mean Test Neg MSE: -0.010794992491901438
# Std Test R²: 0.061706768415444424
# Std Test Neg MSE: 0.0019339027592964616
# --------------------------------------------------
# Params: {'criterion': 'squared_error', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2}
# Mean Test R²: 0.6971722112149212
# Mean Test Neg MSE: -0.011182436769243508
# Std Test R²: 0.08557887399644284
# Std Test Neg MSE: 0.0036573517452428996
# --------------------------------------------------
# Best Cross-Validation R² for pce: 0.7295016306541567
# Best Cross-Validation neg_mean_squared_error for pce: 0.00991306529403881
# Best parameters via GridSearchCV for pce: {'criterion': 'poisson', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 2}

# %%
pd.options.display.max_rows = None
cv_pce_results_df['mean_test_r2']
# Out:
# 1    0.673471
# 2    0.659212
# 3    0.643560
# 4    0.643560
# 0    0.571150
# Name: mean_test_r2, dtype: float64
